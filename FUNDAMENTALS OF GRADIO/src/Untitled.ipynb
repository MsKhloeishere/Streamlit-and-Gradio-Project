# %%
# !pip install gradio
import gradio as gr
import pandas as pd
import joblib
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression

pipeline=joblib.load('pipe.pkl')


def grad(gender, SeniorCitizen, Partner, Dependents, Contract, tenure, MonthlyCharges,

            TotalCharges, PaymentMethod, PhoneService, MultipleLines, InternetService,

            OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV,

            StreamingMovies, PaperlessBilling):
    inputdata = pd.DataFrame({

        'gender': [gender] if gender else ['Male'],  # Replace None with default value

        'SeniorCitizen': [SeniorCitizen] if SeniorCitizen is not None else [0],  # Replace None with default value

        'Partner': [Partner] if Partner else ['No'],  # Replace None with default value

        'Dependents': [Dependents] if Dependents else ['No'],  # Replace None with default value

        'tenure': [tenure] if tenure else [1],  # Replace None with default value

        'PhoneService': [PhoneService] if PhoneService else ['Yes'],  # Replace None with default value

        'MultipleLines': [MultipleLines] if MultipleLines else ['No'],  # Replace None with default value

        'InternetService': [InternetService] if InternetService else ['DSL'],  # Replace None with default value

        'OnlineSecurity': [OnlineSecurity] if OnlineSecurity else ['No'],  # Replace None with default value

        'OnlineBackup': [OnlineBackup] if OnlineBackup else ['No'],  # Replace None with default value

        'DeviceProtection': [DeviceProtection] if DeviceProtection else ['No'],  # Replace None with default value

        'TechSupport': [TechSupport] if TechSupport else ['No'],  # Replace None with default value

        'StreamingTV': [StreamingTV] if StreamingTV else ['No'],  # Replace None with default value

        'StreamingMovies': [StreamingMovies] if StreamingMovies else ['No'],  # Replace None with default value

        'Contract': [Contract] if Contract else ['Month-to-month'],  # Replace None with default value

        'PaperlessBilling': [PaperlessBilling] if PaperlessBilling else ['No'],  # Replace None with default value

        'PaymentMethod': [PaymentMethod] if PaymentMethod else ['Electronic check'],  # Replace None with default value

        'MonthlyCharges': [MonthlyCharges] if MonthlyCharges else [0.0],  # Replace None with default value

        'TotalCharges': [TotalCharges] if TotalCharges else [0.0]  # Replace None with default value

    })
    
    Predict=pipeline.predict(inputdata)
    if Predict[0]=='yes':
        return 'Churn'
    else:
        return 'Not Churn'

# Setting Gradio App Interface

    with gr.Blocks(css=".gradio-container {background-color: grey}") as demo:

        gr.Markdown("# Teleco Customer Churn Prediction #\n*This App allows the user to predict whether a customer will churn or not by entering values in the given fields. Any field left blank takes the default value.*")

        

        # Receiving ALL Input Data here

        gr.Markdown("**Demographic Data**")

        with gr.Row():

            gender = gr.Dropdown(label="Gender", choices=["Male", "Female"])

            SeniorCitizen = gr.Radio(label="Senior Citizen", choices=[1, 0])

            Partner = gr.Radio(label="Partner", choices=["Yes", "No"])

            Dependents = gr.Radio(label="Dependents", choices=["Yes", "No"])




        gr.Markdown("**Service Length and Charges (USD)**")

        with gr.Row():

            Contract = gr.Dropdown(label="Contract", choices=["Month-to-month", "One year", "Two year"])

            tenure = gr.Slider(label="Tenure (months)", minimum=1, step=1, interactive=True)

            MonthlyCharges = gr.Slider(label="Monthly Charges", step=0.05)

            TotalCharges = gr.Slider(label="Total Charges", step=0.05)




        # Phone Service Usage part

        gr.Markdown("**Phone Service Usage**")

        with gr.Row():

            PhoneService = gr.Radio(label="Phone Service", choices=["Yes", "No"])

            MultipleLines = gr.Dropdown(label="Multiple Lines", choices=[

                                        "Yes", "No", "No phone service"])




        # Internet Service Usage part

        gr.Markdown("**Internet Service Usage**")

        with gr.Row():

            InternetService = gr.Dropdown(label="Internet Service", choices=["DSL", "Fiber optic", "No"])

            OnlineSecurity = gr.Dropdown(label="Online Security", choices=["Yes", "No", "No internet service"])

            OnlineBackup = gr.Dropdown(label="Online Backup", choices=["Yes", "No", "No internet service"])

            DeviceProtection = gr.Dropdown(label="Device Protection", choices=["Yes", "No", "No internet service"])

            TechSupport = gr.Dropdown(label="Tech Support", choices=["Yes", "No", "No internet service"])

            StreamingTV = gr.Dropdown(label="TV Streaming", choices=["Yes", "No", "No internet service"])

            StreamingMovies = gr.Dropdown(label="Movie Streaming", choices=["Yes", "No", "No internet service"])




        # Billing and Payment part

        gr.Markdown("**Billing and Payment**")

        with gr.Row():

            PaperlessBilling = gr.Radio(

                label="Paperless Billing", choices=["Yes", "No"])

            PaymentMethod = gr.Dropdown(label="Payment Method", choices=["Electronic check", "Mailed check", "Bank transfer (automatic)", "Credit card (automatic)"])




        # Output Prediction

        output = gr.Text(label="Outcome")

        submit_button = gr.Button("Predict")

        

        submit_button.click(fn= predict,

                            outputs= output,

                            inputs=[gender, SeniorCitizen, Partner, Dependents, Contract, tenure, MonthlyCharges, TotalCharges, PaymentMethod, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, PaperlessBilling],

        

        ),

        

        # Add the reset and flag buttons

        

        def clear():

            output.value = ""

            return None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None

            

        clear_btn = gr.Button("Reset", variant="primary")

        clear_btn.click(fn=clear, inputs=None, outputs=output)

            

    

    demo.launch(inbrowser = True)# Setting Gradio App Interface

    with gr.Blocks(css=".gradio-container {background-color: grey}") as demo:

        gr.Markdown("# Teleco Customer Churn Prediction #\n*This App allows the user to predict whether a customer will churn or not by entering values in the given fields. Any field left blank takes the default value.*")

        

        # Receiving ALL Input Data here

        gr.Markdown("**Demographic Data**")

        with gr.Row():

            gender = gr.Dropdown(label="Gender", choices=["Male", "Female"])

            SeniorCitizen = gr.Radio(label="Senior Citizen", choices=[1, 0])

            Partner = gr.Radio(label="Partner", choices=["Yes", "No"])

            Dependents = gr.Radio(label="Dependents", choices=["Yes", "No"])




        gr.Markdown("**Service Length and Charges (USD)**")

        with gr.Row():

            Contract = gr.Dropdown(label="Contract", choices=["Month-to-month", "One year", "Two year"])

            tenure = gr.Slider(label="Tenure (months)", minimum=1, step=1, interactive=True)

            MonthlyCharges = gr.Slider(label="Monthly Charges", step=0.05)

            TotalCharges = gr.Slider(label="Total Charges", step=0.05)




        # Phone Service Usage part

        gr.Markdown("**Phone Service Usage**")

        with gr.Row():

            PhoneService = gr.Radio(label="Phone Service", choices=["Yes", "No"])

            MultipleLines = gr.Dropdown(label="Multiple Lines", choices=[

                                        "Yes", "No", "No phone service"])




        # Internet Service Usage part

        gr.Markdown("**Internet Service Usage**")

        with gr.Row():

            InternetService = gr.Dropdown(label="Internet Service", choices=["DSL", "Fiber optic", "No"])

            OnlineSecurity = gr.Dropdown(label="Online Security", choices=["Yes", "No", "No internet service"])

            OnlineBackup = gr.Dropdown(label="Online Backup", choices=["Yes", "No", "No internet service"])

            DeviceProtection = gr.Dropdown(label="Device Protection", choices=["Yes", "No", "No internet service"])

            TechSupport = gr.Dropdown(label="Tech Support", choices=["Yes", "No", "No internet service"])

            StreamingTV = gr.Dropdown(label="TV Streaming", choices=["Yes", "No", "No internet service"])

            StreamingMovies = gr.Dropdown(label="Movie Streaming", choices=["Yes", "No", "No internet service"])




        # Billing and Payment part

        gr.Markdown("**Billing and Payment**")

        with gr.Row():

            PaperlessBilling = gr.Radio(

                label="Paperless Billing", choices=["Yes", "No"])

            PaymentMethod = gr.Dropdown(label="Payment Method", choices=["Electronic check", "Mailed check", "Bank transfer (automatic)", "Credit card (automatic)"])




        # Output Prediction

        output = gr.Text(label="Outcome")

        submit_button = gr.Button("Predict")

        

        submit_button.click(fn= predict,

                            outputs= output,

                            inputs=[gender, SeniorCitizen, Partner, Dependents, Contract, tenure, MonthlyCharges, TotalCharges, PaymentMethod, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, PaperlessBilling],

        

        ),

        

        # Add the reset and flag buttons

        

        def clear():

            output.value = ""

            return None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None

            

    clear_btn = gr.Button("Reset", variant="primary")

    clear_btn.click(fn=clear, inputs=None, outputs=output)

        

 

demo.launch(inbrowser = True)
# Out:
# Requirement already satisfied: gradio in c:\users\miss chloe\anaconda3\lib\site-packages (3.35.2)
# Requirement already satisfied: huggingface-hub>=0.14.0 in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (0.15.1)
# Requirement already satisfied: numpy in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from gradio) (1.24.2)
# Requirement already satisfied: orjson in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (3.9.1)
# Requirement already satisfied: pandas in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from gradio) (1.5.3)
# Requirement already satisfied: httpx in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (0.24.1)
# Requirement already satisfied: ffmpy in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (0.3.0)
# Requirement already satisfied: pyyaml in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from gradio) (6.0)
# Requirement already satisfied: fastapi in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (0.98.0)
# Requirement already satisfied: semantic-version in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: matplotlib in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (3.5.2)
# Requirement already satisfied: markupsafe in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from gradio) (2.1.2)
# Requirement already satisfied: gradio-client>=0.2.7 in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (0.2.7)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (0.3.3)
# Requirement already satisfied: aiohttp in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (3.8.4)
# Requirement already satisfied: websockets>=10.0 in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (11.0.3)
# Requirement already satisfied: altair>=4.2.0 in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (5.0.1)
# Requirement already satisfied: pygments>=2.12.0 in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from gradio) (2.14.0)
# Requirement already satisfied: jinja2 in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: pillow in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (9.2.0)
# Requirement already satisfied: pydub in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: pydantic in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (1.10.9)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (2.2.0)
# Requirement already satisfied: requests in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (2.28.1)
# Requirement already satisfied: python-multipart in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (0.0.6)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (0.22.0)
# Requirement already satisfied: aiofiles in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio) (23.1.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from altair>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in c:\users\miss chloe\anaconda3\lib\site-packages (from altair>=4.2.0->gradio) (0.11.2)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\miss chloe\anaconda3\lib\site-packages (from altair>=4.2.0->gradio) (4.3.0)
# Requirement already satisfied: packaging in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from gradio-client>=0.2.7->gradio) (23.0)
# Requirement already satisfied: fsspec in c:\users\miss chloe\anaconda3\lib\site-packages (from gradio-client>=0.2.7->gradio) (2022.7.1)
# Requirement already satisfied: filelock in c:\users\miss chloe\anaconda3\lib\site-packages (from huggingface-hub>=0.14.0->gradio) (3.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\miss chloe\anaconda3\lib\site-packages (from huggingface-hub>=0.14.0->gradio) (4.64.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\miss chloe\anaconda3\lib\site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in c:\users\miss chloe\anaconda3\lib\site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from pandas->gradio) (2022.7.1)
# Requirement already satisfied: click>=7.0 in c:\users\miss chloe\anaconda3\lib\site-packages (from uvicorn>=0.14.0->gradio) (8.0.4)
# Requirement already satisfied: h11>=0.8 in c:\users\miss chloe\anaconda3\lib\site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from aiohttp->gradio) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\miss chloe\anaconda3\lib\site-packages (from aiohttp->gradio) (2.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\miss chloe\anaconda3\lib\site-packages (from aiohttp->gradio) (1.9.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\miss chloe\anaconda3\lib\site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\miss chloe\anaconda3\lib\site-packages (from aiohttp->gradio) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\miss chloe\anaconda3\lib\site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\miss chloe\anaconda3\lib\site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in c:\users\miss chloe\anaconda3\lib\site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: certifi in c:\users\miss chloe\anaconda3\lib\site-packages (from httpx->gradio) (2022.9.14)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in c:\users\miss chloe\anaconda3\lib\site-packages (from httpx->gradio) (0.17.2)
# Requirement already satisfied: sniffio in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: idna in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from httpx->gradio) (3.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\miss chloe\anaconda3\lib\site-packages (from matplotlib->gradio) (1.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\miss chloe\anaconda3\lib\site-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\miss chloe\anaconda3\lib\site-packages (from matplotlib->gradio) (4.34.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\miss chloe\anaconda3\lib\site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\miss chloe\anaconda3\lib\site-packages (from requests->gradio) (1.26.11)
# Requirement already satisfied: colorama in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from click>=7.0->uvicorn>=0.14.0->gradio) (0.4.6)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from httpcore<0.18.0,>=0.15.0->httpx->gradio) (3.6.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.19.3)
# Requirement already satisfied: uc-micro-py in c:\users\miss chloe\anaconda3\lib\site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\miss chloe\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.16.0)
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# C:\Users\MISS CHLOE\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator SimpleImputer from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\MISS CHLOE\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator StandardScaler from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\MISS CHLOE\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator Pipeline from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\MISS CHLOE\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator OneHotEncoder from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\MISS CHLOE\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator ColumnTransformer from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\MISS CHLOE\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator LogisticRegression from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 335
#     327     clear_btn = gr.Button("Reset", variant="primary")
#     329     clear_btn.click(fn=clear, inputs=None, outputs=output)
# --> 335 demo.launch(inbrowser = True)
#
# NameError: name 'demo' is not defined
